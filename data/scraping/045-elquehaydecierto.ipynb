# %%
import json
import w3lib.html
import random
import os
from datetime import datetime
import requests
import string
import calendar
import html
import locale 
from requests_html import HTMLSession
from requests_html import HTML
import validators
import pandas as pd
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
URL_SEED = 'https://www.elquehaydecierto.cl/ubicacion/nacional?page=1'
XPATH_HREF = "//h4/a/@href"

# %%
class Crawler():
    
    USER_AGENT_LIST = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
    ]

    #Ruta XPATH hacia los enlaces que queremos recopilar
    xpath_href=XPATH_HREF

    #variable que permite listar todos los enlaces recopilado
    url_list = []
    
    def _init_(self, URL_SEED, XPATH_HREF):        
        pass

    
    def get(self,url):
        session = HTMLSession()
        header = dict()
        header['user-agent'] = random.choice(self.USER_AGENT_LIST)
        response = session.get(url,headers=header)        
        return response
    
    def parse(self, response):
        self.url_list = []
        urls = response.html.xpath(self.xpath_href)
        for url in urls:
            self.url_list.append(url)

# %%
urls=[]

for page in tqdm(range(3)): # revisemos sólo 2 páginas
    crawler = Crawler()
    response = crawler.get('https://www.elquehaydecierto.cl/ubicacion/nacional?page='+str(page))
    crawler.parse(response)

    
    for url in crawler.url_list:
        urls.append("https://www.elquehaydecierto.cl"+url)

    crawler.url_list = urls
    
crawler.url_list
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ['https://www.elquehaydecierto.cl/noticia/ninguna/el-impactante-testimonio-de-laura-de-la-fuente-tras-baleo-no-quiero-seguir-esperando',
#  'https://www.elquehaydecierto.cl/noticia/economia/heroes-del-emprendimiento-la-infatigable-aventura-de-torcerle-la-mano-al-destino-vi',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/debate-por-comentario-sobre-los-completos-que-se-volvio-viral',
#  'https://www.elquehaydecierto.cl/noticia/economia/banca-etica-realizara-charla-para-empresas-con-foco-en-financiamiento-sostenible',
#  'https://www.elquehaydecierto.cl/noticia/politica/vladimir-putin-y-el-riesgo-de-la-tercera-guerra-mundial',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/el-exabrupto-de-helhue-sukni-en-su-debut-en-mega',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/el-crimen-que-genera-conmocion-encuentran-padre-e-hijo-colgados-en-un-arbol',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/emblematica-periodista-de-canal-13-confirma-en-pantalla-su-alejamiento-de-la-tv',
#  'https://www.elquehaydecierto.cl/noticia/economia/proyecto-adopta-una-colmena-gana-campeonato-nacional-de-emprendimiento',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/ya-esta-muerto-amigo-de-joven-linchado-rompe-el-silencio-y-entrega-desgarrador-testi',
#  'https://www.elquehaydecierto.cl/noticia/politica/subsecretario-miguel-crispi-en-el-dia-de-las-regiones-por-un-chile-regionalista-fem',
#  'https://www.elquehaydecierto.cl/noticia/sociedad/como-reconocer-un-ataque-cerebrovascular',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/complicado-momento-afecta-maria-gracia-omegna-y-preocupa-seguidores',
#  'https://www.elquehaydecierto.cl/noticia/economia/mapa-constituyente-las-regiones-al-banco-central',
#  'https://www.elquehaydecierto.cl/noticia/guerra/la-oportunidad-de-reemplazar-el-petroleo-y-el-gas-rusos-con-energias-renovables',
#  'https://www.elquehaydecierto.cl/noticia/tecnologia/wom-impacta-con-disruptivo-lanzamiento-de-red-5g-en-chile-y-con-ambicioso-plan-de',
#  'https://www.elquehaydecierto.cl/noticia/economia/cuando-es-el-primer-black-friday-de-2022',
#  'https://www.elquehaydecierto.cl/noticia/sociedad/como-midea-se-convirtio-en-la-empresa-n-1-en-la-fabricacion-de-aire-acondicionado-y',
#  'https://www.elquehaydecierto.cl/noticia/listado/soap-solidario-un-sencillo-tramite-puede-cambiar-la-vida-de-quienes-mas-lo-necesitan',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/mala-jugada-contra-maximo-bolocco-zulemita-menem-se-frota-las-manos',
#  'https://www.elquehaydecierto.cl/noticia/economia/como-lograr-que-una-empresa-familiar-sea-exitosa-y-perdure-video',
#  'https://www.elquehaydecierto.cl/noticia/politica/daniel-jadue-manifesto-su-postura-contra-la-prision-politica-con-guino-boric',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/la-foto-que-delato-visita-chile-de-protagonistas-de-el-precio-de-la-historia',
#  'https://www.elquehaydecierto.cl/noticia/economia/inversion-en-startups-por-que-este-tipo-de-emprendimientos-atrae-inversionistas',
#  'https://www.elquehaydecierto.cl/noticia/sociedad/becas-santander-ingles-ultimo-dia-para-postular-para-estudiar-gratis-y-con-cupos-li',
#  'https://www.elquehaydecierto.cl/noticia/ninguna/indignacion-por-comportamiento-de-coni-santa-maria-en-emision-del-cortometraje-besti',
#  'https://www.elquehaydecierto.cl/noticia/sociedad/alguien-esta-de-acuerdo-la-drastica-y-criticada-accion-que-realizo-un-profesor-cont',
#  'https://www.elquehaydecierto.cl/noticia/sociedad/se-tenia-que-decir-y-se-dijo-mail-la-profe-sobre-el-uso-de-la-falda-y-los-comentari',
#  'https://www.elquehaydecierto.cl/noticia/politica/camila-vallejo-condeno-incidente-en-que-joven-termino-baleado-por-carabinero',
#  'https://www.elquehaydecierto.cl/noticia/cambio-climatico/la-hora-del-planeta-por-la-proteccion-del-medio-ambiente-manana-las-2030',
#  'https://www.elquehaydecierto.cl/noticia/sociedad/fondo-concursable-adjudica-mas-de-235-millones-proyectos-de-desarrollo-comunitario',
#  'https://www.elquehaydecierto.cl/noticia/cultura/lollapalooza-chile-2022-lo-bueno-lo-malo-y-lo-por-mejorar',
#  'https://www.elquehaydecierto.cl/noticia/politica/daniel-jadue-cuestiono-decision-de-gobierno-de-boric-de-no-apoyar-quinto-retiro',
#  'https://www.elquehaydecierto.cl/noticia/beca/becas-santander-ingles-postulaciones-abiertas-y-cupos-limitados-informate-e-inscribete-',
#  'https://www.elquehaydecierto.cl/noticia/politica/cristian-warnken-en-bad-boys-con-parisi-sobre-convencion-constituyente-quiero-trans',
#  'https://www.elquehaydecierto.cl/noticia/sociedad/estudio-evidencia-la-fragilidad-de-la-proteccion-social-en-chile']

# %%
len(urls)
# Out:
# 36

# %%
urls[0]
# Out:
# 'https://www.elquehaydecierto.cl/noticia/ninguna/el-impactante-testimonio-de-laura-de-la-fuente-tras-baleo-no-quiero-seguir-esperando'

# %%
URL_NEWS = urls[0]
XPATH_TITLE = "//h1"
XPATH_CONTENT ="//div[@class='content content-node']//p"

# %%
class Scraper:
    
    USER_AGENT_LIST = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
    ]

    query_extract_title = XPATH_TITLE
    query_extract_text =  XPATH_CONTENT

    def _init_(self):
        pass
   
    def get(self,url):
        headers = {'user-agent':random.choice(self.USER_AGENT_LIST) }
        session = HTMLSession()
        response = session.get(url,headers=headers) 
        return response
    
    def clean_text(self, html_text):
        text_without_tags = w3lib.html.remove_tags(html_text)
        text_without_escape_chars = w3lib.html.replace_escape_chars(text_without_tags)
        text_without_escape_chars = html.unescape(text_without_escape_chars)
        text_without_whitespace = text_without_escape_chars.strip()
        return text_without_whitespace

    
    #### main function ####
    def parse(self, response):
        
        #URL
        self.news_url = response.url
        
        #TITLE
        self.news_title = response.html.xpath(self.query_extract_title)[0].text
        self.news_title = self.clean_text(self.news_title)
       
        
        #CONTENT
        self.news_text = ""
        
        html_paragraphs = response.html.xpath(self.query_extract_text)
        
        for paragraph in html_paragraphs:
            paragraph_content = w3lib.html.remove_tags(paragraph.text)    
            text_cleaned = self.clean_text(paragraph_content)
            self.news_text = self.news_text+text_cleaned

# %%
scraper = Scraper()
response =scraper.get(URL_NEWS)

# %%
scraper.parse(response)

# %%
scraper.news_title
# Out:
# 'El impactante testimonio de Laura de La Fuente tras baleo: “No quiero seguir esperando”'

# %%
scraper.news_text
# Out:
# 'A poco menos de un mes del asalto que sufrió Cristián de La Fuente y su hija Laura de La Fuente, esta última volvió a aparecer en eventos de masividad. Esta vez, logró su primera salida y participación en un evento que celebró Adidas en el Parque Araucano, comuna de Las Condes.Pese a tener que movilizarse a través de silla de ruedas, “Laurita” no tuvo impedimento alguno en acudir a la cita.En diálogo con Radio ADN, la joven esbozó que tras el baleo en su contra, decidió emprender otra mirada de la vida. “Ahora más que nunca quiero hacer todo, pero hoy, dentro de lo posible y cuando pueda, voy a hacer todo. No quiero seguir esperando, la vida está para vivirla”, dijo.Así también valoró el esfuerzo de sus padres, quienes han sido un pilar fundamental en su evolución. “No me siento sola. El seguir adelante es lo que yo puedo hacer. Quiero volver a hacer deporte, tengo todas esas metas claras”, declaró Laura.Hasta la fecha hay dos detenidos por este connotado caso.'

# %%
#Verificamos que el scraper devuelve algo
assert(len(scraper.news_title)>0)
assert(len(scraper.news_text)>0)

# %%
df = pd.DataFrame(data={'url': [URL_NEWS],'title':[scraper.news_title], 'content':[scraper.news_text]})
df
# Out:
#                                                  url  \
# 0  https://www.elquehaydecierto.cl/noticia/ningun...
#
#                                                title  \
# 0  El impactante testimonio de Laura de La Fuente...
#
#                                              content
# 0  A poco menos de un mes del asalto que sufrió C...

# %%
XPATH_TITLE = "//h1"
XPATH_CONTENT ="//div[@class='content content-node']//p"

for url in tqdm(urls):
    URL_NEWS = url
    scraper = Scraper()
    response =scraper.get(URL_NEWS)
    scraper.parse(response)
    df1 = pd.DataFrame(data={'url': url, 'title':scraper.news_title, 'content':scraper.news_text},index=['url', 'title', 'content'])
    df = df.append(df1, ignore_index=True)
df = df.drop_duplicates()
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]

# %%
df
# Out:
#                                                    url  \
# 0    https://www.elquehaydecierto.cl/noticia/ningun...
# 4    https://www.elquehaydecierto.cl/noticia/econom...
# 7    https://www.elquehaydecierto.cl/noticia/ningun...
# 10   https://www.elquehaydecierto.cl/noticia/econom...
# 13   https://www.elquehaydecierto.cl/noticia/politi...
# 16   https://www.elquehaydecierto.cl/noticia/ningun...
# 19   https://www.elquehaydecierto.cl/noticia/ningun...
# 22   https://www.elquehaydecierto.cl/noticia/ningun...
# 25   https://www.elquehaydecierto.cl/noticia/econom...
# 28   https://www.elquehaydecierto.cl/noticia/ningun...
# 31   https://www.elquehaydecierto.cl/noticia/politi...
# 34   https://www.elquehaydecierto.cl/noticia/socied...
# 37   https://www.elquehaydecierto.cl/noticia/ningun...
# 40   https://www.elquehaydecierto.cl/noticia/econom...
# 43   https://www.elquehaydecierto.cl/noticia/guerra...
# 46   https://www.elquehaydecierto.cl/noticia/tecnol...
# 49   https://www.elquehaydecierto.cl/noticia/econom...
# 52   https://www.elquehaydecierto.cl/noticia/socied...
# 55   https://www.elquehaydecierto.cl/noticia/listad...
# 58   https://www.elquehaydecierto.cl/noticia/ningun...
# 61   https://www.elquehaydecierto.cl/noticia/econom...
# 64   https://www.elquehaydecierto.cl/noticia/politi...
# 67   https://www.elquehaydecierto.cl/noticia/ningun...
# 70   https://www.elquehaydecierto.cl/noticia/econom...
# 73   https://www.elquehaydecierto.cl/noticia/socied...
# 76   https://www.elquehaydecierto.cl/noticia/ningun...
# 79   https://www.elquehaydecierto.cl/noticia/socied...
# 82   https://www.elquehaydecierto.cl/noticia/socied...
# 85   https://www.elquehaydecierto.cl/noticia/politi...
# 88   https://www.elquehaydecierto.cl/noticia/cambio...
# 91   https://www.elquehaydecierto.cl/noticia/socied...
# 94   https://www.elquehaydecierto.cl/noticia/cultur...
# 97   https://www.elquehaydecierto.cl/noticia/politi...
# 100  https://www.elquehaydecierto.cl/noticia/beca/b...
# 103  https://www.elquehaydecierto.cl/noticia/politi...
# 106  https://www.elquehaydecierto.cl/noticia/socied...
#
#                                                  title  \
# 0    El impactante testimonio de Laura de La Fuente...
# 4    Héroes del emprendimiento: La infatigable aven...
# 7    Debate por comentario sobre los completos que ...
# 10   Banca Ética realizará charla para empresas con...
# 13   Vladímir Putin y el riesgo de la tercera guerr...
# 16   El "exabrupto" de Helhue Sukni en su debut en ...
# 19   El crimen que genera conmoción: Encuentran a p...
# 22   Emblemática periodista de Canal 13 confirma en...
# 25   Proyecto “Adopta una Colmena” gana campeonato ...
# 28   “Ya está muerto…”: Amigo de joven linchado rom...
# 31   Subsecretario Miguel Crispi en el Día de las R...
# 34          ¿Cómo reconocer un Ataque Cerebrovascular?
# 37   Complicado momento afecta a María Gracia Omegn...
# 40   Mapa Constituyente: ¿Las regiones al Banco Cen...
# 43   La oportunidad de reemplazar el petróleo y el ...
# 46   WOM impacta con disruptivo lanzamiento de red ...
# 49            Cuándo es el primer Black Friday de 2022
# 52   ¿Cómo Midea se convirtió en la empresa N° 1 en...
# 55   SOAP Solidario: Un sencillo trámite puede camb...
# 58   ¿Mala jugada contra Máximo Bolocco?: Zulemita ...
# 61   ¿Cómo lograr que una empresa familiar sea exit...
# 64   Daniel Jadue manifestó su postura contra la pr...
# 67   La foto que delató visita a Chile de protagoni...
# 70   Inversión en startups: por qué este tipo de em...
# 73   Becas Santander inglés: ¡Último día para postu...
# 76   Indignación por “comportamiento” de Coni Santa...
# 79   ¿Alguien está de acuerdo?: La drástica y criti...
# 82   Se tenía que decir y se dijo: Mail a la profe ...
# 85   Camila Vallejo condenó incidente en que joven ...
# 88   La Hora del Planeta: por la protección del med...
# 91   Fondo concursable adjudica más de $235 millone...
# 94   Lollapalooza Chile 2022: Lo bueno, lo malo y l...
# 97   Daniel Jadue cuestionó decisión de gobierno de...
# 100  Becas Santander inglés: Postulaciones abiertas...
# 103  Cristian Warnken en Bad Boys con Parisi sobre ...
# 106  Estudio evidencia la fragilidad de la protecci...
#
#                                                content
# 0    A poco menos de un mes del asalto que sufrió C...
# 4    Blanca habla con el corazón y les garantizo qu...
# 7    Es un hecho que los completos que comemos en C...
# 10   El próximo jueves 7 de abril, de 9 a 11 horas,...
# 13   Por George Soros, fundador y presidente de Ope...
# 16   La popular abogada e influencer, Helhue Sukni,...
# 19   Un chat de unos vecinos alertó a la policía de...
# 22   La periodista Carola Urrejola contó en vivo qu...
# 25   El campeonato nacional de emprendimiento Nada ...
# 28   Un doloroso testimonio entregó Fabio, amigo de...
# 31   Por Miguel Crispi SerranoSubsecretario de Desa...
# 34   En Chile, el Ataque Cerebrovascular, ACV, acab...
# 37   La actriz María Gracia Omegna no lo está pasan...
# 40   Si bien en principio hay acuerdo en que el órg...
# 43   Por Helen Clark ex primera ministra de Nueva Z...
# 46   A un año de que WOM se posicionara como el úni...
# 49   Varias multitiendas vinien anunciando ofertas ...
# 52   Midea nació en 1968 en China como una compañía...
# 55   El Seguro Obligatorio de Accidentes Personales...
# 58   Fue durante una entrevista con el medio argent...
# 61   La profesionalización, incorporación de nuevas...
# 64   El alcalde de Recoleta Daniel Jadue reafirmó s...
# 67   "¿Quiéres vender o empeñar?", es la frase segu...
# 70   Durante los últimos años la industria de Ventu...
# 73   Todavía tienes tiempo para inscribirte para es...
# 76   Nuevamente la periodista Constanza Santa María...
# 79   Totalmente indignadas quedaron las madres y pa...
# 82   Hola profesora:Esperando que se encuentre bien...
# 85   La ministra secretaria de Gobierno Camila Vall...
# 88   “Aún podemos frenar el cambio climático y la p...
# 91   Con la colaboración como un motor que moviliza...
# 94   Por R. Stark y C. RuizTras 2 años de silencio ...
# 97   El alclade de Recoleta Daniel Jadue (PC) criti...
# 100  Aprender un segundo idioma se ha vuelto una ha...
# 103  El programa Bad Boys de Franco Parisi y su gen...
# 106  El estudio Desafíos de la Protección Social en...
