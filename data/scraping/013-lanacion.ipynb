# %%
import json
import w3lib.html
import random
import os
from datetime import datetime
import requests
import string
import calendar
import html
import locale 
from requests_html import HTMLSession
from requests_html import HTML
import validators
import pandas as pd
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
URL_SEED = "'https://www.lanacion.cl/category/nacional/page/1/'"
XPATH_HREF = "//h3/a/@href"

# %%
class Crawler():
    
    USER_AGENT_LIST = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
    ]

    #Ruta XPATH hacia los enlaces que queremos recopilar
    xpath_href=XPATH_HREF

    #variable que permite listar todos los enlaces recopilado
    url_list = []
    
    def _init_(self, URL_SEED, XPATH_HREF):        
        pass

    
    def get(self,url):
        session = HTMLSession()
        header = dict()
        header['user-agent'] = random.choice(self.USER_AGENT_LIST)
        response = session.get(url,headers=header)        
        return response
    
    def parse(self, response):
        self.url_list = []
        urls = response.html.xpath(self.xpath_href)
        for url in urls:
            self.url_list.append(url)

# %%
urls=[]

for page in tqdm(range(3)): # revisemos sólo 2 páginas
    crawler = Crawler()
    response = crawler.get('https://www.lanacion.cl/category/nacional/page/'+str(page))
    crawler.parse(response)

    
    for url in crawler.url_list:
        urls.append(url)

    crawler.url_list = urls
    
crawler.url_list
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ['https://www.lanacion.cl/gpm-recomienda-incrementar-la-tasa-de-politica-monetaria-en-175-puntos-base/',
#  'https://www.lanacion.cl/vallejo-llamo-a-no-adelantar-juicios-tras-incidente-de-carabinero-en-marcha/',
#  'https://www.lanacion.cl/brigada-de-cibercrimen-indagara-amenaza-de-masacre-en-liceo-industrial-benjamin-franklin-de-quinta-normal/',
#  'https://www.lanacion.cl/reportan-nuevo-suicidio-al-interior-de-mall-costanera-center/',
#  'https://www.lanacion.cl/detallan-intervencion-contra-comercio-ilegal-en-luis-thayer-ojeda/',
#  'https://www.lanacion.cl/delegada-de-la-rm-anuncio-trabajo-coordinado-ante-primer-dia-del-joven-combatiente-en-gobierno-de-boric/',
#  'https://www.lanacion.cl/la-gente-ya-esta-cabreada-con-el-uso-de-mascarilla-alcalde-de-chile-chico-por-eliminacion-de-ordenanza/',
#  'https://www.lanacion.cl/convencion-comision-de-sistemas-de-justicia-aprueba-el-fin-del-fiscal-nacional/',
#  'https://www.lanacion.cl/jadue-por-nombramiento-de-figueroa-tiene-todas-las-capacidades/',
#  'https://www.lanacion.cl/colegio-de-profesores-tildo-de-gravisimas-las-amenazas-a-liceo-de-quinta-normal-clases-fueron-suspendidas/',
#  'https://www.lanacion.cl/especialistas-destacan-sostenido-enlentecimiento-de-la-pandemia-pero-advierten-que-algunos-indicadores-siguen-criticos/',
#  'https://www.lanacion.cl/patricio-fernandez-sobre-el-proceso-constituyente-es-un-cambio-necesario/',
#  'https://www.lanacion.cl/gobierno-descarta-aumento-en-impuesto-al-diesel-por-escenario-internacional/',
#  'https://www.lanacion.cl/gobierno-extendio-hasta-junio-el-decreto-de-emergencia-hidrica-en-231-comunas/',
#  'https://www.lanacion.cl/estudiantes-protestan-con-barricadas-afuera-del-liceo-de-aplicacion/',
#  'https://www.lanacion.cl/gpm-recomienda-incrementar-la-tasa-de-politica-monetaria-en-175-puntos-base/',
#  'https://www.lanacion.cl/vallejo-llamo-a-no-adelantar-juicios-tras-incidente-de-carabinero-en-marcha/',
#  'https://www.lanacion.cl/brigada-de-cibercrimen-indagara-amenaza-de-masacre-en-liceo-industrial-benjamin-franklin-de-quinta-normal/',
#  'https://www.lanacion.cl/reportan-nuevo-suicidio-al-interior-de-mall-costanera-center/',
#  'https://www.lanacion.cl/guillermo-maripan-estaria-descartado-para-el-decisivo-duelo-ante-uruguay/',
#  'https://www.lanacion.cl/gpm-recomienda-incrementar-la-tasa-de-politica-monetaria-en-175-puntos-base
#  'https://www.lanacion.cl/este-martes-comienza-en-francia-juicio-contra-chileno-nicolas-zepeda-acusado-de-desaparicion-y-muerte-de-la-exnovia/',
#  'https://www.lanacion.cl/warnken-y-la-convencion-hay-minorias-que-no-han-sido-escuchadas-y-no-son-solo-las-minorias-de-la-derecha/',
#  'https://www.lanacion.cl/subsecretario-de-prevencion-del-delito-no-podemos-tolerar-la-violencia-hacia-las-policias/',
#  'https://www.lanacion.cl/encapuchados-queman-camion-en-la-comuna-de-tirua-chofer-fue-emboscado-y-amenazado/',
#  'https://www.lanacion.cl/cadem-desaprobacion-del-presidente-boric-subio-10-puntos-y-al-57-le-parecio-mal-que-barbara-figueroa-sea-embajadora/',
#  'https://www.lanacion.cl/nunca-habia-visto-gente-tan-egocentrica-doctora-cordero-hablo-de-como-es-el-ambiente-en-el-congreso/',
#  'https://www.lanacion.cl/gobernador-de-la-araucania-no-estoy-de-acuerdo-con-beneficio-a-primos-tralcal/',
#  'https://www.lanacion.cl/tres-detenidos-por-robar-piezas-de-motocicletas-fueron-arrestados-tras-persecucion-en-curacavi/',
#  'https://www.lanacion.cl/vallejo-y-el-5-retiro-una-cosa-es-acudir-a-una-medida-desesperante-pero-otra-es-hacerla-una-politica-publica/',
#  'https://www.lanacion.cl/gpm-recomienda-incrementar-la-tasa-de-politica-monetaria-en-175-puntos-base/',
#  'https://www.lanacion.cl/vallejo-llamo-a-no-adelantar-juicios-tras-incidente-de-carabinero-en-marcha/',
#  'https://www.lanacion.cl/brigada-de-cibercrimen-indagara-amenaza-de-masacre-en-liceo-industrial-benjamin-franklin-de-quinta-normal/',
#  'https://www.lanacion.cl/reportan-nuevo-suicidio-al-interior-de-mall-costanera-center/',
#  'https://www.lanacion.cl/guillermo-maripan-estaria-descartado-para-el-decisivo-duelo-ante-uruguay/']

# %%
len(urls)
# Out:
# 60

# %%
urls[0]
# Out:
# 'https://www.lanacion.cl/gpm-recomienda-incrementar-la-tasa-de-politica-monetaria-en-175-puntos-base/'

# %%
URL_NEWS = urls[0]
XPATH_TITLE = "//h1"
XPATH_CONTENT ="//div[@class='tdb-block-inner td-fix-index']//p"

# %%
class Scraper:
    
    USER_AGENT_LIST = [
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"
    ]

    query_extract_title = XPATH_TITLE
    query_extract_text =  XPATH_CONTENT

    def _init_(self):
        pass
   
    def get(self,url):
        headers = {'user-agent':random.choice(self.USER_AGENT_LIST) }
        session = HTMLSession()
        response = session.get(url,headers=headers) 
        return response
    
    def clean_text(self, html_text):
        text_without_tags = w3lib.html.remove_tags(html_text)
        text_without_escape_chars = w3lib.html.replace_escape_chars(text_without_tags)
        text_without_escape_chars = html.unescape(text_without_escape_chars)
        text_without_whitespace = text_without_escape_chars.strip()
        return text_without_whitespace

    
    #### main function ####
    def parse(self, response):
        
        #URL
        self.news_url = response.url
        
        #TITLE
        self.news_title = response.html.xpath(self.query_extract_title)[0].text
        self.news_title = self.clean_text(self.news_title)
       
        
        #CONTENT
        self.news_text = ""
        
        html_paragraphs = response.html.xpath(self.query_extract_text)
        
        for paragraph in html_paragraphs:
            paragraph_content = w3lib.html.remove_tags(paragraph.text)    
            text_cleaned = self.clean_text(paragraph_content)
            self.news_text = self.news_text+text_cleaned

# %%
scraper = Scraper()
response =scraper.get(URL_NEWS)

# %%
scraper.parse(response)

# %%
scraper.news_title
# Out:
# 'GPM recomienda incrementar la Tasa de Política Monetaria en 175 puntos base'

# %%
scraper.news_text
# Out:
# 'El Grupo de Política Monetaria, en su reunión mensual, recomendó al Banco Central por unanimidad incrementar la Tasa de Política Monetaria en 175 puntos base, para situarla en un nivel de 7,25%, manteniendo un sesgo contractivo para su próximo movimiento.En el último mes, producto de la guerra en Ucrania, la economía mundial se ha visto enfrentada a un nuevo shock de oferta que perjudica el crecimiento económico del mundo y reaviva la presiones inflacionarias a nivel internacional.Es frente a este panorama que el Grupo de Política Monetaria (GPM) en su reunión mensual recomendó al Banco Central por unanimidad incrementar la Tasa de Política Monetaria en 175 puntos base, para situarla en un nivel de 7,25%, manteniendo un sesgo contractivo para su próximo movimiento.En la conferencia llevada a cabo por los expertos en materias macroeconómicas Carlos Budnevich, Tomás Izquierdo, Juan Pablo Medina y los académicos de la Facultad de Economía y Negocios de la Universidad de Chile (FEN), Guillermo Le Fort y Eugenia Andreasen, plantearon que el escenario global conformado por este conflicto internacional “incrementan la incertidumbre por sobre lo que ya era una perspectiva económica y financiera incierta antes del inicio de esta guerra”.A raíz de lo anterior, y de este nuevo shock de oferta a nivel internacional, “se espera genere en el mundo desarrollado una reducción en el crecimiento económico a 3% e impulse un alza en la inflación la que se situaría en torno a 5% en el presente año”.En tanto, a nivel nacional, los académicos señalaron que la inflación continúa mostrando un alza importante, situándose en febrero pasado en 7,8% en doce meses, producto un sobre calentamiento de la actividad económica interna, una importante depreciación del peso chileno en meses previos y en parte por mayores niveles de inflación a nivel internacional.“Los propios estudios del Banco Central indican como el principal componente de los efectos inflacionarios que estamos viviendo en Chile a situaciones propiamente domésticas”, señala el académico Carlos Budnevich. En esa misma línea con el actual desborde inflacionario, el alza anual de los salarios nominales en enero 2022 mostró niveles récord que no se observaban desde hace más de una década (7,5% 12M).Por otra parte, el comunicado señala que otro factor adicional que dificulta aún más la tarea de controlar los niveles de inflación proviene del riesgo que representa que las expectativas de inflación a 1 y 2 años plazo mantengan o aumenten su divergencia respecto del centro del rango meta de inflación de 3% anual.“Un tema a tener en cuenta es que sigue habiendo una cierta presión latente, porque parte de los retiros todavía generan una gran liquidez que tienen los hogares y que se mantienen en los sistemas financieros”, comenta Eugenia Andreasen.Si bien el crecimiento de la economía chilena ha ido desacelerándose desde mediados del 2021, alcanzando una expansión en enero de 2022 de 9,6% en 12 meses, la actividad no minera sigue creciendo al 11,5% anual y, hasta enero pasado, incrementándose trimestre a trimestre.Es por todo el escenario antes expuesto y por la necesidad de contener pronto la creciente inflación y el eventual surgimiento de una espiral de salarios y precios, así como de romper el desanclaje de las expectativas de inflación, que el grupo de expertos recomiendan acentuar con prontitud el carácter contractivo de la política monetaria.'

# %%
#Verificamos que el scraper devuelve algo
assert(len(scraper.news_title)>0)
assert(len(scraper.news_text)>0)

# %%
df = pd.DataFrame(data={'url': [URL_NEWS],'title':[scraper.news_title], 'content':[scraper.news_text]})
df
# Out:
#                                                  url  \
# 0  https://www.lanacion.cl/gpm-recomienda-increme...
#
#                                                title  \
# 0  GPM recomienda incrementar la Tasa de Política...
#
#                                              content
# 0  El Grupo de Política Monetaria, en su reunión ...

# %%
XPATH_TITLE = "//h1"
XPATH_CONTENT ="//div[@class='tdb-block-inner td-fix-index']//p"

for url in tqdm(urls):
    URL_NEWS = url
    scraper = Scraper()
    response =scraper.get(URL_NEWS)
    scraper.parse(response)
    df1 = pd.DataFrame(data={'url': url, 'title':scraper.news_title, 'content':scraper.news_text.replace(".",". ")},index=['url', 'title', 'content'])
    df = df.append(df1, ignore_index=True)
df = df.drop_duplicates()
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]

# %%
df
# Out:
#                                                    url  \
# 0    https://www.lanacion.cl/gpm-recomienda-increme...
# 4    https://www.lanacion.cl/vallejo-llamo-a-no-ade...
# 7    https://www.lanacion.cl/brigada-de-cibercrimen...
# 10   https://www.lanacion.cl/reportan-nuevo-suicidi...
# 13   https://www.lanacion.cl/detallan-intervencion-...
# 16   https://www.lanacion.cl/delegada-de-la-rm-anun...
# 19   https://www.lanacion.cl/la-gente-ya-esta-cabre...
# 22   https://www.lanacion.cl/convencion-comision-de...
# 25   https://www.lanacion.cl/gpm-recomienda-increme...
# 28   https://www.lanacion.cl/vallejo-llamo-a-no-ade...
# 31   https://www.lanacion.cl/brigada-de-cibercrimen...
# 34   https://www.lanacion.cl/reportan-nuevo-suicidi...
# 37   https://www.lanacion.cl/detallan-intervencion-...
# 40   https://www.lanacion.cl/delegada-de-la-rm-anun...
# 43   https://www.lanacion.cl/la-gente-ya-esta-cabre...
# 46   https://www.lanacion.cl/convencion-comision-de...
# 49   https://www.lanacion.cl/jadue-por-nombramiento...
# 52   https://www.lanacion.cl/colegio-de-profesores-...
# 55   https://www.lanacion.cl/especialistas-destacan...
# 58   https://www.lanacion.cl/patricio-fernandez-sob...
# 61   https://www.lanacion.cl/gobierno-descarta-aume...
# 64   https://www.lanacion.cl/gobierno-extendio-hast...
# 67   https://www.lanacion.cl/estudiantes-protestan-...
# 82   https://www.lanacion.cl/guillermo-maripan-esta...
# 160  https://www.lanacion.cl/despues-supe-que-eran-...
# 163  https://www.lanacion.cl/este-martes-comienza-e...
# 166  https://www.lanacion.cl/warnken-y-la-convencio...
# 169  https://www.lanacion.cl/subsecretario-de-preve...
# 172  https://www.lanacion.cl/encapuchados-queman-ca...
# 175  https://www.lanacion.cl/cadem-desaprobacion-de...
# 178  https://www.lanacion.cl/nunca-habia-visto-gent...
# 181  https://www.lanacion.cl/gobernador-de-la-arauc...
# 184  https://www.lanacion.cl/tres-detenidos-por-rob...
# 187  https://www.lanacion.cl/vallejo-y-el-5-retiro-...
#
#                                                  title  \
# 0    GPM recomienda incrementar la Tasa de Política...
# 4    Vallejo llamó a “no adelantar juicios” tras in...
# 7    Brigada de Cibercrimen indagará amenaza de “ma...
# 10   Reportan nuevo suicidio al interior de mall Co...
# 13   Detallan intervención contra comercio ilegal e...
# 16   Delegada de la RM anunció “trabajo coordinado”...
# 19   “La gente ya está cabreada con el uso de masca...
# 22   Convención: comisión de Sistemas de Justicia a...
