# %%
import textnets as tn
tn.params["seed"] = 42

# %%
import pandas as pd

import ast
def tokens_to_list(text):
    text = text[1:-1]
    res = ast.literal_eval(text)
    return list(dict(res).keys())


clusters = pd.read_csv("../../data/bertopic.csv")
clusters = clusters[1:]
clusters= clusters.set_index('Name')
clusters.head()
# Out:
#                                                 Topic  Count  \
# Name
# 0_accidente_conductor_vehículo_colisión             0    451
# 1_salmón_salmones_industria_consejo salmón          1    293
# 2_robo_robos_vehículo_delincuentes                  2    293
# 3_bomberos_incendio_cuerpo bomberos_emergencia      3    260
# 4_sexual_abuso_abuso sexual_sexuales                4    251
#
#                                                                                  most_freq_tokens
# Name
# 0_accidente_conductor_vehículo_colisión         [('accidente', 0.013147867844274892), ('conduc...
# 1_salmón_salmones_industria_consejo salmón      [('salmón', 0.011826029962445547), ('salmones'...
# 2_robo_robos_vehículo_delincuentes              [('robo', 0.0142556776557684), ('robos', 0.006...
# 3_bomberos_incendio_cuerpo bomberos_emergencia  [('bomberos', 0.017599120600600864), ('incendi...
# 4_sexual_abuso_abuso sexual_sexuales            [('sexual', 0.014554316451458877), ('abuso', 0...

# %%
clusters['tokens'] = clusters.most_freq_tokens.apply(lambda x: str(tokens_to_list(x)))

# %%
salud = clusters[clusters['tokens'].str.contains('salud')]
salud
# Out:
#                                                     Topic  Count  \
# Name
# 9_hospital_salud_servicio salud_hospital ancud          9    188
# 26_casos activos_asociadas virus_causas asociad...     26    115
# 33_mental_salud mental_salud_ansiedad                  33     96
# 35_casos_contagios_nuevos casos_cifra                  35     93
# 47_casos_exámenes_test_positividad                     47     79
# 63_obesidad_dieta_alimentos_nutrición                  63     60
# 64_pandemia_turismo_salud_medidas                      64     58
# 83_contagios_virus_casos_dosis                         83     45
# 88_casos_contagios_río negro_provincia                 88     43
# 108_discapacidad_síndrome down_adultos_personas...    108     39
# 114_mariscos_marea roja_toxina_mariscos contami...    114     36
# 119_farmacia_medicamentos_farmacia vecina_farma...    119     34
# 123_casos_coronavirus_tratamiento intermedio_salud    123     33
# 137_tratamiento intermedio_regional ministerial...    137     30
# 144_dosis_vacunación_cuarta dosis_dosis refuerzo      144     29
# 145_mariscos_toxinas_marea roja_bivalvos              145     29
# 150_variante ómicron_nueva variante_casos_países      150     27
# 155_provincia osorno_san_río negro_seremi salud       155     26
# 170_vacunación_vacunarse_dosis refuerzo_ministe...    170     25
# 188_casos_casos activos_región_camas uci              188     22
# 195_escolar_padres_convivencia escolar_niños          195     22
# 204_casos_hepatitis_dosis_virus                       204     21
# 225_innovación_pymes_emprendedores_productos          225     20
# 242_ambiental_corte suprema_cumplimiento_municipio    242     18
# 257_física_inactividad física_muscular_activida...    257     17
# 272_confirmados región_autoridad sanitaria deta...    272     16
# 275_zhong_rebrote_cero_pauta completa                 275     16
# 284_atención primaria_comisión salud_fundación ...    284     15
# 296_salud_pacientes_casos_dosis refuerzo              296     14
# 301_senda darwin_proyecto_north karelia_univers...    301     14
# 308_casos_dosis refuerzo_contagios_salud              308     14
# 315_región lagos reportó_lagos reportó_torno cu...    315     14
# 348_fin año_contagios_casos_salud                     348     12
# 351_endemia_casos_enfermedad_vergara                  351     12
# 379_epilepsia_convulsiones_servicio salud_salud       379     11
# 383_vencidas_vacunas_salud_dosis                      383     11
# 386_tuberculosis_tratamiento_enfermedad_servici...    386     11
# 418_pacientes_hospital_hospital base_atención         418     10
# 436_provincia palena_provincia_municipalidades ...    436     10
#
#                                                                                      most_freq_tokens  \
# Name
# 9_hospital_salud_servicio salud_hospital ancud      [('hospital', 0.014874700526929772), ('salud',...
# 26_casos activos_asociadas virus_causas asociad...  [('casos activos', 0.010288380583916023), ('as...
# 33_mental_salud mental_salud_ansiedad               [('mental', 0.014615182564590809), ('salud men...
# 35_casos_contagios_nuevos casos_cifra               [('casos', 0.010670285591966845), ('contagios'...
# 47_casos_exámenes_test_positividad                  [('casos', 0.007975782933085502), ('exámenes',...
# 63_obesidad_dieta_alimentos_nutrición               [('obesidad', 0.009864805602746217), ('dieta',...
# 64_pandemia_turismo_salud_medidas                   [('pandemia', 0.0047947614943302744), ('turism...
# 83_contagios_virus_casos_dosis                      [('contagios', 0.008241734361890848), ('virus'...
# 88_casos_contagios_río negro_provincia              [('casos', 0.016499313808898377), ('contagios'...
# 108_discapacidad_síndrome down_adultos_personas...  [('discapacidad', 0.008305020171761207), ('sín...
# 114_mariscos_marea roja_toxina_mariscos contami...  [('mariscos', 0.026753265879238847), ('marea r...
# 119_farmacia_medicamentos_farmacia vecina_farma...  [('farmacia', 0.02242052722896136), ('medicame...
# 123_casos_coronavirus_tratamiento intermedio_salud  [('casos', 0.00934543051730414), ('coronavirus...
# 137_tratamiento intermedio_regional ministerial...  [('tratamiento intermedio', 0.0125552937446380...
# 144_dosis_vacunación_cuarta dosis_dosis refuerzo    [('dosis', 0.017459430005102555), ('vacunación...
# 145_mariscos_toxinas_marea roja_bivalvos            [('mariscos', 0.023547260373396973), ('toxinas...
# 150_variante ómicron_nueva variante_casos_países    [('variante ómicron', 0.009108754186603675), (...
# 155_provincia osorno_san_río negro_seremi salud     [('provincia osorno', 0.014011809798512026), (...
# 170_vacunación_vacunarse_dosis refuerzo_ministe...  [('vacunación', 0.011942676458191446), ('vacun...
# 188_casos_casos activos_región_camas uci            [('casos', 0.016099328212581022), ('casos acti...
# 195_escolar_padres_convivencia escolar_niños        [('escolar', 0.009890830856095763), ('padres',...
# 204_casos_hepatitis_dosis_virus                     [('casos', 0.011593990391489407), ('hepatitis'...
# 225_innovación_pymes_emprendedores_productos        [('innovación', 0.01246134587273772), ('pymes'...
# 242_ambiental_corte suprema_cumplimiento_municipio  [('ambiental', 0.010971101358710628), ('corte ...
# 257_física_inactividad física_muscular_activida...  [('física', 0.017440829259764857), ('inactivid...
# 272_confirmados región_autoridad sanitaria deta...  [('confirmados región', 0.017817291723777016),...
# 275_zhong_rebrote_cero_pauta completa               [('zhong', 0.010549050596997933), ('rebrote', ...
# 284_atención primaria_comisión salud_fundación ...  [('atención primaria', 0.006822299872545596), ...
# 296_salud_pacientes_casos_dosis refuerzo            [('salud', 0.007070231285615428), ('pacientes'...
# 301_senda darwin_proyecto_north karelia_univers...  [('senda darwin', 0.011242860324787886), ('pro...
# 308_casos_dosis refuerzo_contagios_salud            [('casos', 0.00908648406812382), ('dosis refue...
# 315_región lagos reportó_lagos reportó_torno cu...  [('región lagos reportó', 0.029463114722498386...
# 348_fin año_contagios_casos_salud                   [('fin año', 0.00802797212867235), ('contagios...
# 351_endemia_casos_enfermedad_vergara                [('endemia', 0.009843494142725217), ('casos', ...
# 379_epilepsia_convulsiones_servicio salud_salud     [('epilepsia', 0.03619822484901053), ('convuls...
# 383_vencidas_vacunas_salud_dosis                    [('vencidas', 0.018791954662097817), ('vacunas...
# 386_tuberculosis_tratamiento_enfermedad_servici...  [('tuberculosis', 0.05417913822294014), ('trat...
# 418_pacientes_hospital_hospital base_atención       [('pacientes', 0.012549177017119346), ('hospit...
# 436_provincia palena_provincia_municipalidades ...  [('provincia palena', 0.021254947097218743), (...
#
#                                                                                                tokens
# Name
# 9_hospital_salud_servicio salud_hospital ancud      ['hospital', 'salud', 'servicio salud', 'hospi...
# 26_casos activos_asociadas virus_causas asociad...  ['casos activos', 'asociadas virus', 'causas a...
# 33_mental_salud mental_salud_ansiedad               ['mental', 'salud mental', 'salud', 'ansiedad'...
# 35_casos_contagios_nuevos casos_cifra               ['casos', 'contagios', 'nuevos casos', 'cifra'...
# 47_casos_exámenes_test_positividad                  ['casos', 'exámenes', 'test', 'positividad', '...
# 63_obesidad_dieta_alimentos_nutrición               ['obesidad', 'dieta', 'alimentos', 'nutrición'...
# 64_pandemia_turismo_salud_medidas                   ['pandemia', 'turismo', 'salud', 'medidas', 's...
# 83_contagios_virus_casos_dosis                      ['contagios', 'virus', 'casos', 'dosis', 'vacu...
# 88_casos_contagios_río negro_provincia              ['casos', 'contagios', 'río negro', 'provincia...
# 108_discapacidad_síndrome down_adultos_personas...  ['discapacidad', 'síndrome down', 'adultos', '...
# 114_mariscos_marea roja_toxina_mariscos contami...  ['mariscos', 'marea roja', 'toxina', 'mariscos...
# 119_farmacia_medicamentos_farmacia vecina_farma...  ['farmacia', 'medicamentos', 'farmacia vecina'...
# 123_casos_coronavirus_tratamiento intermedio_salud  ['casos', 'coronavirus', 'tratamiento intermed...
# 137_tratamiento intermedio_regional ministerial...  ['tratamiento intermedio', 'regional ministeri...
# 144_dosis_vacunación_cuarta dosis_dosis refuerzo    ['dosis', 'vacunación', 'cuarta dosis', 'dosis...
# 145_mariscos_toxinas_marea roja_bivalvos            ['mariscos', 'toxinas', 'marea roja', 'bivalvo...
# 150_variante ómicron_nueva variante_casos_países    ['variante ómicron', 'nueva variante', 'casos'...
# 155_provincia osorno_san_río negro_seremi salud     ['provincia osorno', 'san', 'río negro', 'sere...
# 170_vacunación_vacunarse_dosis refuerzo_ministe...  ['vacunación', 'vacunarse', 'dosis refuerzo', ...
# 188_casos_casos activos_región_camas uci            ['casos', 'casos activos', 'región', 'camas uc...
# 195_escolar_padres_convivencia escolar_niños        ['escolar', 'padres', 'convivencia escolar', '...
# 204_casos_hepatitis_dosis_virus                     ['casos', 'hepatitis', 'dosis', 'virus', 'caso...
# 225_innovación_pymes_emprendedores_productos        ['innovación', 'pymes', 'emprendedores', 'prod...
# 242_ambiental_corte suprema_cumplimiento_municipio  ['ambiental', 'corte suprema', 'cumplimiento',...
# 257_física_inactividad física_muscular_activida...  ['física', 'inactividad física', 'muscular', '...
# 272_confirmados región_autoridad sanitaria deta...  ['confirmados región', 'autoridad sanitaria de...
# 275_zhong_rebrote_cero_pauta completa               ['zhong', 'rebrote', 'cero', 'pauta completa',...
# 284_atención primaria_comisión salud_fundación ...  ['atención primaria', 'comisión salud', 'funda...
# 296_salud_pacientes_casos_dosis refuerzo            ['salud', 'pacientes', 'casos', 'dosis refuerz...
# 301_senda darwin_proyecto_north karelia_univers...  ['senda darwin', 'proyecto', 'north karelia', ...
# 308_casos_dosis refuerzo_contagios_salud            ['casos', 'dosis refuerzo', 'contagios', 'salu...
# 315_región lagos reportó_lagos reportó_torno cu...  ['región lagos reportó', 'lagos reportó', 'tor...
# 348_fin año_contagios_casos_salud                   ['fin año', 'contagios', 'casos', 'salud', 'me...
# 351_endemia_casos_enfermedad_vergara                ['endemia', 'casos', 'enfermedad', 'vergara', ...
# 379_epilepsia_convulsiones_servicio salud_salud     ['epilepsia', 'convulsiones', 'servicio salud'...
# 383_vencidas_vacunas_salud_dosis                    ['vencidas', 'vacunas', 'salud', 'dosis', 'ser...
# 386_tuberculosis_tratamiento_enfermedad_servici...  ['tuberculosis', 'tratamiento', 'enfermedad', ...
# 418_pacientes_hospital_hospital base_atención       ['pacientes', 'hospital', 'hospital base', 'at...
# 436_provincia palena_provincia_municipalidades ...  ['provincia palena', 'provincia', 'municipalid...

# %%
#!py -m spacy download es_core_news_sm

# %%
corpus = tn.Corpus.from_df(salud, doc_col="tokens", lang="es_core_news_sm")

# %%
corpus
# Out:
# <Corpus with 39 documents using language model 'es_core_news_sm'>

# %%
t = tn.Textnet(corpus.tokenized(), min_docs=1)

# %%
t.plot(label_nodes=True)

# %%
papers = t.project(node_type="doc")
papers.plot(label_nodes=True)

# %%
words = t.project(node_type="term")
words.top_betweenness()
# Out:
# atención     5282.5
# sanitario    4999.5
# seremi       4668.0
# físico       4453.0
# mental       4230.0
# emocional    3709.5
# fundación    3520.0
# mundial      2987.5
# persona      2705.5
# saludable    2516.0
# dtype: float64

# %% [markdown]
# words.plot(label_nodes=True,
#            scale_nodes_by="betweenness",
#            color_clusters=True,
#            alpha=0.5,
#            edge_width=[10*w for w in words.edges["weight"]],
#            edge_opacity=0.4,
#            node_label_filter=lambda n: n.betweenness() > words.betweenness.median()
#           )

# %%
topic_name = t.project(node_type="doc")
topic_name.plot(label_nodes=True)

# %%
topic_name.top_betweenness()
# Out:
# 33_mental_salud mental_salud_ansiedad                                                                        70.0
# 296_salud_pacientes_casos_dosis refuerzo                                                                     65.0
# 284_atención primaria_comisión salud_fundación liderazgo_fundación liderazgo chile                           60.0
# 272_confirmados región_autoridad sanitaria detallando_confirmó autoridad sanitaria_así confirmó autoridad    50.0
# 35_casos_contagios_nuevos casos_cifra                                                                        47.0
# 64_pandemia_turismo_salud_medidas                                                                            33.0
# 379_epilepsia_convulsiones_servicio salud_salud                                                              31.0
# 88_casos_contagios_río negro_provincia                                                                       30.0
# 145_mariscos_toxinas_marea roja_bivalvos                                                                     30.0
# 315_región lagos reportó_lagos reportó_torno cuidados_torno cuidados críticos                                29.0
# dtype: float64

# %%
plot = topic_name.plot(
        label_nodes=True,
        label_edges=True,
        node_label_filter=lambda v: v.degree() > 15 and v.degree() < 30, # >36
        edge_label_filter=lambda e: e["weight"] > 1000,
    )
plot

# %% [markdown]
# https://textnets.readthedocs.io/en/stable/_modules/textnets/corpus.html
#
# https://textnets.readthedocs.io/en/stable/index.html
#
# https://textnets.readthedocs.io/en/stable/advanced.html
