# %%
from tqdm import tqdm # Barra de progreso


import transformers
transformers.__version__
# Out:
# '4.21.1'

# %%
#!pip install protobuf==3.20.*

# %%
model_name = "finiteautomata/beto-sentiment-analysis"

from transformers import AutoTokenizer, AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
from transformers import pipeline
nlp = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %% [markdown]
# ### _Test con los títulos de noticias_

# %%
import pandas as pd
df = pd.read_csv("../../data/bertopic.csv")
df.drop(['topic'], axis=1, inplace=True)

print(len(df))
df.head()
# Out:
# 29321
#          date      media_outlet  \
# 0  2021-10-01  elheraldoaustral
# 1  2021-10-01  elheraldoaustral
# 2  2021-10-01  elheraldoaustral
# 3  2021-10-01  elheraldoaustral
# 4  2021-10-01  elheraldoaustral
#
#                                                  url  \
# 0  https://www.eha.cl/noticia/local/reconocen-a-g...
# 1  https://www.eha.cl/noticia/local/con-nuevos-ma...
# 2  https://www.eha.cl/noticia/local/centro-de-sal...
# 3  https://www.eha.cl/noticia/local/alcalde-tomas...
# 4  https://www.eha.cl/noticia/local/galeria-de-ar...
#
#                                                title  \
# 0  Reconocen a guardaparques de la Región de Los ...
# 1  Con nuevos materiales comienza plan piloto en ...
# 2  Centro de Salud Familiar CESFAM Puerto Varas i...
# 3  Alcalde Tomás Gárate presidió por primera vez ...
# 4  Galería de Arte Machacoya realizará remate de ...
#
#                                                 text  \
# 0  Distintos protagonistas de los parques naciona...
# 1  Centro de negocios Sercotec coordina acuerdos ...
# 2  Las horas se solicitan en el SOME o bien a tra...
# 3  Los y las consejeras destacaron el hecho de vo...
# 4  Hoy viernes a las 18:30 horas, en Machacoya At...
#
#                                              content  \
# 0  reconocen guardaparques región lagos actores c...
# 1  nuevos materiales comienza plan piloto saltos ...
# 2  centro salud familiar cesfam puerto varas invi...
# 3  alcalde tomás gárate presidió primera vez octa...
# 4  galería arte machacoya realizará remate obras ...
#
#                        comuna date_clustering  \
# 0      ['puyehue', 'chaiten']         2021-10
# 1            ['puerto varas']         2021-10
# 2            ['puerto varas']         2021-10
# 3  ['castro', 'puerto varas']         2021-10
# 4                         NaN         2021-10
#
#                                               tokens  \
# 0  ['reconocen', 'guardaparques', 'region', 'lago...
# 1  ['nuevos', 'materiales', 'comienza', 'plan', '...
# 2  ['centro', 'salud', 'familiar', 'cesfam', 'pue...
# 3  ['alcalde', 'tomas', 'garate', 'presidio', 'pr...
# 4  ['galeria', 'arte', 'machacoya', 'realizara', ...
#
#                                                  doc  topics
# 0  reconocen guardaparques region lagos actores c...      -1
# 1  nuevos materiales comienza plan piloto saltos ...      -1
# 2  centro salud familiar cesfam puerto vara invit...       2
# 3  alcalde tomas garate presidio primera vez octa...      -1
# 4  galeria arte machacoya realizara remate obras ...       0

# %%
sub = df[:100].copy()
sub['title_label'] = ""
sub['title_score'] = ""

for index, row in tqdm(sub.iterrows(), desc='sub rows - sentiment', total=sub.shape[0]):
    
    # Analizamos su sentimiento en inglés
    sentiment_value = nlp(row['title'])
    
    # Insertamos en dataframe
    sub.at[index, "title_label"] = sentiment_value[0].get('label')
    sub.at[index, "title_score"] = sentiment_value[0].get('score')
# Out:
# sub rows - sentiment: 100%|██████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.84it/s]

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None, 'display.max_colwidth', None)
sub[['title', "title_label", 'title_score']]
# Out:
#                                                                                                                               title  \
# 0                                        Reconocen a guardaparques de la Región de Los Lagos como actores claves en la conservación
# 1                                                                 Con nuevos materiales comienza plan piloto en Saltos del Petrohué
# 2   Centro de Salud Familiar CESFAM Puerto Varas invita a prevenir el Cáncer Cervicouterino con extensión horaria para exámenes PAP
# 3        Alcalde Tomás Gárate presidió por primera vez la octava sesión del Consejo Comunal de la Sociedad Civil COSOC Puerto Varas
# 4                                                        Galería de Arte Machacoya realizará remate de obras de artistas de la zona
# 5                                                    Municipio llamará a licitación construcción de pasarela peatonal en Los Notros
# 6                                                               3era Mesa de Reactivación Económica circunscribe su radio de acción
# 7                                                    Gremio médico rechaza cierre de camas críticas implementadas en Hospital Ancud
# 8                                                Asistentes de educación municipal en Osorno verán incrementadas sus remuneraciones
# 9                                                                        CONADI llama a renovar directivas de comunidades indígenas
# 10                                                                    Tasa de desocupación en la región de Los Lagos fue de un 3,4%
# 11                                                      Se constituyó nuevo Comité para la Gestión del Riesgo de Desastres (COGRID)
# 12                                                                          ¿Qué debemos saber de los medicamentos para la alergia?
# 13                                                       ¿Pagarán el IFE hasta el 2022?: Conoce detalles de la propuesta de senador
# 14                                                                Conductores del DAEM Puerto Montt llegan a acuerdo y deponen paro
# 15                                            "Desaparece": Hermana de Sichel hizo llamado luego de polémica entrevista de su padre
# 16                                        Estudiantes denuncian que CFT Estatal Los Lagos no les da un lugar estable donde estudiar
# 17                                                    Consulta con tu RUT si puedes cobrar el Bono Base Familiar de $28 mil mensual
# 18                                                   Cuenta RUT: ¿Cuál es el monto máximo que puedo gastar en el Cyber Monday 2021?
# 19                                                     Exitoso operativo de fisiatría se realizó en Hospital Comunitario de Queilen
# 20                     Festival “Cultura por Fibra” y II Encuentro Provincial de Artistas Visuales se toman los panoramas en Castro
# 21                                       Comunidad valora compromiso y acciones implementadas en el Hospital Comunitario de Queilen
# 22           Audiencia de Preparación de Juicio Oral será el 3 de noviembre: Fiscalía acusó a ex Alcalde Berger por Fraude al Fisco
# 23                                                Alcaldes de la Cuenca firmaron compromiso con Plan de Acción ZOIT Lago Llanquihue
# 24                                                                                    Cesfam Entre Lagos mejora su infraestructura.
# 25                                    VIALIDAD Y GOBERNADOR REGIONAL COMPROMETEN IMPORTANTES AVANCES EN CONECTIVIDAD PARA PURRANQUE
# 26                                                                      DIPUTADO FIDEL ESPINOZA VISITA A DIRECTOR DE DHARMA COLLEGE
# 27                                                                Joven dio a luz en baño del Hospital de Osorno: bebé nació muerto
# 28                                                                                          Joven ciclista es atropellada en Osorno
# 29                           Positiva evaluación de Carabineros tras primera noche sin toque de queda en la provincia de Llanquihue
# 30                                                     23 nuevos contagios de covid-19 presentó la región de Los Lagos este viernes
# 31                                                  FF.AA realizaron más de 12 millones de fiscalizaciones en 561 días en la región
# 32                                             Más de 2 mil 800 postulaciones para fondos concursables recibió San Juan de La Costa
# 33                                                                               Acercan atención de salud a los vecinos de Trincao
# 34                                                                    Puqueldón avanza a apertura en el fin del Estado de Excepción
# 35                                                                                 Municipio firma convenio para ejecutar proyectos
# 36                                                                                Celebran Día de la Rabia con acciones preventivas
# 80                                                      Un 17 % de los hogares de la región está compuesto sólo por adultos mayores
# 81                                    Los Lagos: plantean que el SAG debe retomar la labor de rescate de animales y aves silvestres
# 82                                         Sichel admite que hizo retiros previsionales y desata ola de críticas de sus contendores
# 83                                                              Con seminario y visita a parque chilote parte la Semana del Turismo
# 84                           Contraloría declara inconstitucional decreto del Gobierno que buscaba mantener FF.AA. en Macrozona Sur
# 85                                                             Controversia: reglamento de la Convención sancionará el negacionismo
# 86                                      Desempleo cae a 8,5% y trabajadores informales aumentaron 38,3% entre junio y agosto pasado
# 87                                                                                  Fiscalía: aumenta tasa de homicidios consumados
# 88                                                                   Fuerte aumento de casos nuevos marca el fin del toque de queda
# 89                                                       Condenan a Sarkozy a un año de cárcel por financiamiento ilegal de campaña
# 90                                        Ecuador: militares intervienen cárcel donde una guerra de bandas dejó 116 reos fallecidos
# 91                                                                         Rey emérito Juan Carlos I: "Aquí no molesto a la corona"
# 92                                                          Argentina: la pobreza baja al 40,6%, pero crece el número de indigentes
# 93                                                                           Jair Bolsonaro pone como "ejemplo" a niño con un fusil
# 94                                                    Presidente de grupo que ofrece suicidio asistido, es detenido en países bajos
# 95                                    UN estudio sostiene que marte fue modelado por violentas inundaciones de cráteres DESBORDADOS
# 96                                                                Leverkusen y Betis se lucen en la fase grupal de la Europa League
# 97                                                      Colo Colo pierde en casa ante Ñublense y queda a tiro de cañón de La Calera
# 98                                                     Vinculan a Diego Costa en una trama de irregularidades de portal de apuestas
# 99                                                                    Descubren que resultados de boxeo olímpico fueron manipulados
#
#    title_label title_score
# 0          POS    0.953994
# 1          NEU    0.927708
# 2          NEU    0.994852
# 3          NEU    0.944004
# 4          NEU    0.995532
# 5          NEU     0.99521
# 6          NEU    0.972454
# 7          NEU    0.973984
# 8          NEU    0.992781
# 9          NEU    0.990752
# 10         NEG    0.995607
# 11         NEU    0.981968
# 12         NEU    0.994546
# 13         NEU     0.99868
# 14         NEU    0.995753
# 15         NEU    0.995982
# 16         NEG    0.998562
# 17         NEU    0.998715
# 18         NEU    0.994665
# 19         NEU     0.99285
# 20         NEU    0.608706
# 21         POS    0.973288
# 22         NEU    0.958543
# 23         NEU    0.994226
# 24         POS    0.920584
# 25         POS    0.993801
# 26         NEU    0.933105
# 27         NEU    0.634458
# 28         NEG    0.992902
# 29         POS    0.923524
# 30         NEU     0.94364
# 31         NEU    0.785119
# 32         POS    0.736429
# 33         NEU    0.982524
# 34         NEG    0.892469
# 35         NEU    0.990357
# 36         NEU    0.997283
# 37         NEU    0.952645
# 38         NEU    0.987559
# 39         NEU    0.996011
# 40         NEG    0.845691
# 41         NEU    0.998881
# 42         NEU    0.974176
# 43         NEU    0.523176
# 44         NEU    0.996881
# 45         NEU     0.96946
# 46         NEU    0.991463
# 47         NEU    0.998748
# 48         NEG    0.996605
# 49         NEU    0.970076
# 50         NEU    0.998037
# 51         NEG    0.961463
# 52         NEU    0.889042
# 53         NEG    0.997701
# 54         NEU    0.984087
# 55         NEU    0.994991
# 56         NEU    0.997941
# 57         NEU    0.598198
# 58         NEU    0.970917
# 59         NEU    0.979001
# 60         NEU     0.99719
# 61         NEU       0.972
# 62         NEU    0.955956
# 63         NEU    0.991336
# 64         NEU    0.997084
# 65         NEU    0.869672
# 66         NEU    0.995141
# 67         NEU    0.567196
# 68         POS     0.99602
# 69         NEG    0.537462
# 70         NEU    0.941086
# 71         NEU    0.998074
# 72         NEU    0.994223
# 73         NEG    0.990974
# 74         NEG    0.966903
# 75         NEU     0.99398
# 76         NEU    0.995983
# 77         NEU    0.955277
# 78         POS    0.993535
# 79         NEU    0.966491
# 80         NEU    0.889886
# 81         NEU    0.953804
# 82         NEG    0.991885
# 83         POS    0.965341
# 84         NEG    0.877515
# 85         NEU     0.99597
# 86         NEG    0.921233
# 87         NEG     0.92147
# 88         NEG     0.95717
# 89         NEG    0.551793
# 90         NEG    0.997315
# 91         NEU    0.996245
# 92         NEU    0.723335
# 93         NEU    0.895624
# 94         NEG    0.997088
# 95         NEU    0.952928
# 96         NEU    0.987974
# 97         NEG    0.739885
# 98         NEG    0.990294
# 99         NEG    0.932127

# %% [markdown]
# ### Estructura de una noticia
# Según [Wikipedia](https://es.wikipedia.org/wiki/Noticia), una noticia está compuesta por las siguientes secciones:
#
# - **Epígrafe o antetítulo**: Se sitúa al lector en el contexto sobre el que se va a hablar.
# - **El título**: Se trata de resumir la información en un número limitado de palabras. El título debe despertar el interés del público, tomando en cuenta, dos elementos clave de la noticia como lo son la precisión y la concisión.
# - **Bajada o subtítulo**: Aporta información adicional que resume brevemente lo sucedido.
# - **Entradilla, copete o lead**: Es el primer párrafo de la noticia, en el cual se deben concentrar los datos más relevantes del hecho y/o del acontecimiento. Si el título atrae al público, el lead debe confirmar su interés.
# - **El cuerpo**: Se desarrolla a profundidad lo descrito en el lead. En esta parte de la noticia, se deben ir desglosando los datos del hecho en un orden de mayor a menor importancia, siguiendo la estructura de la pirámide invertida
# - **Cierre o remate**: Es el último párrafo de la nota, denominado remate, tiene por función “cerrar” la noticia; darle a entender al receptor que la noticia allí precisamente se concluye.
#
#
# En base a lo anterior, se diseñará una estrategia que permita acercarnos más en la obtención del grado de polaridad de una noticia.
#
# - <u>Estrategia 1</u>: Analizar el lead (_Puesto que no podemos exceder cierta cantidad de caracteres en el análisis de sentimiento, es necesario particionar el content_)
#
# err: Token indices sequence length is longer than the specified maximum sequence length for this model (1265 > 512). Running this sequence through the model will result in indexing errors
# sub rows - lead_sentiment:   0%|

# %%
sub['lead_label'] = ""

for index, row in tqdm(sub.iterrows(), desc='sub rows - lead_sentiment', total=sub.shape[0]):
    count_neutral = 0
    count_negative = 0
    count_positive = 0
    
    partition = row['text'].split(".")
    for text in partition:
        # Analizamos su sentimiento
        sentiment_value = nlp(text)
        if sentiment_value[0].get('label') == "NEU": count_neutral=count_neutral+1
        if sentiment_value[0].get('label') == "NEG": count_negative=count_negative+1
        if sentiment_value[0].get('label') == "POS": count_positive=count_positive+1
    
    sub.at[index, "lead_label"] = {"NEU": count_neutral, 
                                   "NEG": count_negative,
                                   "POS": count_positive}
# Out:
# sub rows - lead_sentiment: 100%|█████████████████████████████████████████████████████| 100/100 [02:07<00:00,  1.27s/it]

# %%
sub[['title', "title_label", 'title_score', "lead_label"]]
# Out:
# 81                                    Los Lagos: plantean que el SAG debe retomar la labor de rescate de animales y aves silvestres
# 82                                         Sichel admite que hizo retiros previsionales y desata ola de críticas de sus contendores
# 83                                                              Con seminario y visita a parque chilote parte la Semana del Turismo
# 84                           Contraloría declara inconstitucional decreto del Gobierno que buscaba mantener FF.AA. en Macrozona Sur
# 85                                                             Controversia: reglamento de la Convención sancionará el negacionismo
# 86                                      Desempleo cae a 8,5% y trabajadores informales aumentaron 38,3% entre junio y agosto pasado
# 87                                                                                  Fiscalía: aumenta tasa de homicidios consumados
# 88                                                                   Fuerte aumento de casos nuevos marca el fin del toque de queda
# 89                                                       Condenan a Sarkozy a un año de cárcel por financiamiento ilegal de campaña
# 90                                        Ecuador: militares intervienen cárcel donde una guerra de bandas dejó 116 reos fallecidos
# 91                                                                         Rey emérito Juan Carlos I: "Aquí no molesto a la corona"
# 92                                                          Argentina: la pobreza baja al 40,6%, pero crece el número de indigentes
# 93                                                                           Jair Bolsonaro pone como "ejemplo" a niño con un fusil
# 94                                                    Presidente de grupo que ofrece suicidio asistido, es detenido en países bajos
# 95                                    UN estudio sostiene que marte fue modelado por violentas inundaciones de cráteres DESBORDADOS
# 96                                                                Leverkusen y Betis se lucen en la fase grupal de la Europa League
# 97                                                      Colo Colo pierde en casa ante Ñublense y queda a tiro de cañón de La Calera
# 98                                                     Vinculan a Diego Costa en una trama de irregularidades de portal de apuestas
# 99                                                                    Descubren que resultados de boxeo olímpico fueron manipulados
#
#    title_label title_score                        lead_label
# 0          POS    0.953994  {'NEU': 13, 'NEG': 0, 'POS': 14}
# 1          NEU    0.927708    {'NEU': 3, 'NEG': 0, 'POS': 6}
# 2          NEU    0.994852   {'NEU': 14, 'NEG': 0, 'POS': 0}
# 3          NEU    0.944004    {'NEU': 8, 'NEG': 0, 'POS': 0}
# 4          NEU    0.995532    {'NEU': 3, 'NEG': 0, 'POS': 4}
# 5          NEU     0.99521    {'NEU': 5, 'NEG': 0, 'POS': 1}
# 6          NEU    0.972454   {'NEU': 12, 'NEG': 0, 'POS': 1}
# 7          NEU    0.973984    {'NEU': 2, 'NEG': 2, 'POS': 1}
# 8          NEU    0.992781    {'NEU': 4, 'NEG': 0, 'POS': 4}
# 9          NEU    0.990752   {'NEU': 11, 'NEG': 0, 'POS': 0}
# 10         NEG    0.995607    {'NEU': 9, 'NEG': 4, 'POS': 2}
# 11         NEU    0.981968   {'NEU': 17, 'NEG': 0, 'POS': 1}
# 12         NEU    0.994546   {'NEU': 14, 'NEG': 4, 'POS': 0}
# 13         NEU     0.99868    {'NEU': 7, 'NEG': 0, 'POS': 1}
# 14         NEU    0.995753    {'NEU': 5, 'NEG': 5, 'POS': 0}
# 15         NEU    0.995982  {'NEU': 10, 'NEG': 12, 'POS': 1}
# 16         NEG    0.998562    {'NEU': 4, 'NEG': 4, 'POS': 0}
# 17         NEU    0.998715   {'NEU': 10, 'NEG': 2, 'POS': 0}
# 18         NEU    0.994665   {'NEU': 10, 'NEG': 0, 'POS': 0}
# 19         NEU     0.99285    {'NEU': 7, 'NEG': 0, 'POS': 3}
# 20         NEU    0.608706    {'NEU': 7, 'NEG': 0, 'POS': 7}
# 21         POS    0.973288    {'NEU': 4, 'NEG': 1, 'POS': 4}
# 22         NEU    0.958543   {'NEU': 13, 'NEG': 2, 'POS': 0}
# 23         NEU    0.994226    {'NEU': 4, 'NEG': 0, 'POS': 2}
# 24         POS    0.920584    {'NEU': 8, 'NEG': 0, 'POS': 0}
# 25         POS    0.993801   {'NEU': 10, 'NEG': 0, 'POS': 2}
# 26         NEU    0.933105    {'NEU': 3, 'NEG': 2, 'POS': 0}
# 27         NEU    0.634458    {'NEU': 9, 'NEG': 3, 'POS': 0}
# 28         NEG    0.992902    {'NEU': 3, 'NEG': 2, 'POS': 0}
# 29         POS    0.923524    {'NEU': 3, 'NEG': 0, 'POS': 2}
# 30         NEU     0.94364    {'NEU': 7, 'NEG': 1, 'POS': 0}
# 31         NEU    0.785119    {'NEU': 7, 'NEG': 2, 'POS': 0}
# 32         POS    0.736429   {'NEU': 12, 'NEG': 0, 'POS': 2}
# 33         NEU    0.982524    {'NEU': 6, 'NEG': 0, 'POS': 6}
# 34         NEG    0.892469   {'NEU': 21, 'NEG': 2, 'POS': 1}
# 35         NEU    0.990357    {'NEU': 6, 'NEG': 0, 'POS': 2}
# 36         NEU    0.997283    {'NEU': 4, 'NEG': 0, 'POS': 1}
# 37         NEU    0.952645    {'NEU': 5, 'NEG': 0, 'POS': 0}
# 38         NEU    0.987559    {'NEU': 6, 'NEG': 2, 'POS': 0}
# 39         NEU    0.996011   {'NEU': 12, 'NEG': 0, 'POS': 0}
# 40         NEG    0.845691   {'NEU': 12, 'NEG': 7, 'POS': 0}
# 41         NEU    0.998881    {'NEU': 9, 'NEG': 1, 'POS': 0}
# 42         NEU    0.974176    {'NEU': 7, 'NEG': 5, 'POS': 0}
# 43         NEU    0.523176  {'NEU': 20, 'NEG': 13, 'POS': 0}
# 44         NEU    0.996881    {'NEU': 7, 'NEG': 1, 'POS': 0}
# 45         NEU     0.96946   {'NEU': 13, 'NEG': 8, 'POS': 0}
# 46         NEU    0.991463   {'NEU': 15, 'NEG': 4, 'POS': 3}
# 47         NEU    0.998748   {'NEU': 14, 'NEG': 7, 'POS': 1}
# 48         NEG    0.996605    {'NEU': 5, 'NEG': 7, 'POS': 1}
# 49         NEU    0.970076   {'NEU': 11, 'NEG': 6, 'POS': 0}
# 50         NEU    0.998037    {'NEU': 4, 'NEG': 0, 'POS': 0}
# 51         NEG    0.961463    {'NEU': 4, 'NEG': 0, 'POS': 0}
# 52         NEU    0.889042    {'NEU': 3, 'NEG': 0, 'POS': 0}
# 53         NEG    0.997701    {'NEU': 8, 'NEG': 5, 'POS': 3}
# 54         NEU    0.984087    {'NEU': 8, 'NEG': 2, 'POS': 0}
# 55         NEU    0.994991    {'NEU': 5, 'NEG': 1, 'POS': 7}
# 56         NEU    0.997941    {'NEU': 4, 'NEG': 0, 'POS': 1}
# 57         NEU    0.598198    {'NEU': 6, 'NEG': 1, 'POS': 0}
# 58         NEU    0.970917    {'NEU': 3, 'NEG': 1, 'POS': 0}
# 59         NEU    0.979001    {'NEU': 7, 'NEG': 0, 'POS': 0}
# 60         NEU     0.99719  {'NEU': 15, 'NEG': 10, 'POS': 2}
# 61         NEU       0.972   {'NEU': 10, 'NEG': 2, 'POS': 4}
# 62         NEU    0.955956    {'NEU': 8, 'NEG': 1, 'POS': 0}
# 63         NEU    0.991336   {'NEU': 12, 'NEG': 3, 'POS': 2}
# 64         NEU    0.997084   {'NEU': 10, 'NEG': 1, 'POS': 0}
# 65         NEU    0.869672    {'NEU': 9, 'NEG': 1, 'POS': 0}
# 66         NEU    0.995141    {'NEU': 6, 'NEG': 6, 'POS': 0}
# 67         NEU    0.567196    {'NEU': 5, 'NEG': 3, 'POS': 0}
# 68         POS     0.99602    {'NEU': 4, 'NEG': 0, 'POS': 6}
# 69         NEG    0.537462    {'NEU': 6, 'NEG': 0, 'POS': 3}
# 70         NEU    0.941086    {'NEU': 4, 'NEG': 0, 'POS': 0}
# 71         NEU    0.998074    {'NEU': 6, 'NEG': 0, 'POS': 1}
# 72         NEU    0.994223   {'NEU': 15, 'NEG': 1, 'POS': 2}
# 73         NEG    0.990974   {'NEU': 22, 'NEG': 9, 'POS': 3}
# 74         NEG    0.966903   {'NEU': 11, 'NEG': 3, 'POS': 0}
# 75         NEU     0.99398   {'NEU': 16, 'NEG': 2, 'POS': 2}
# 76         NEU    0.995983    {'NEU': 7, 'NEG': 0, 'POS': 1}
# 77         NEU    0.955277    {'NEU': 7, 'NEG': 0, 'POS': 2}
# 78         POS    0.993535    {'NEU': 4, 'NEG': 0, 'POS': 0}
# 79         NEU    0.966491   {'NEU': 29, 'NEG': 3, 'POS': 4}
# 80         NEU    0.889886   {'NEU': 12, 'NEG': 1, 'POS': 1}
# 81         NEU    0.953804    {'NEU': 5, 'NEG': 3, 'POS': 0}
# 82         NEG    0.991885  {'NEU': 14, 'NEG': 12, 'POS': 1}
# 83         POS    0.965341   {'NEU': 15, 'NEG': 0, 'POS': 6}
# 84         NEG    0.877515   {'NEU': 11, 'NEG': 2, 'POS': 0}
# 85         NEU     0.99597   {'NEU': 15, 'NEG': 9, 'POS': 0}
# 86         NEG    0.921233    {'NEU': 5, 'NEG': 4, 'POS': 1}
# 87         NEG     0.92147    {'NEU': 7, 'NEG': 4, 'POS': 0}
# 88         NEG     0.95717    {'NEU': 6, 'NEG': 1, 'POS': 0}
# 89         NEG    0.551793   {'NEU': 12, 'NEG': 9, 'POS': 2}
# 90         NEG    0.997315    {'NEU': 7, 'NEG': 3, 'POS': 0}
# 91         NEU    0.996245   {'NEU': 20, 'NEG': 3, 'POS': 0}
# 92         NEU    0.723335    {'NEU': 5, 'NEG': 6, 'POS': 0}
# 93         NEU    0.895624   {'NEU': 12, 'NEG': 1, 'POS': 1}
# 94         NEG    0.997088   {'NEU': 14, 'NEG': 7, 'POS': 2}
# 95         NEU    0.952928   {'NEU': 11, 'NEG': 5, 'POS': 0}
# 96         NEU    0.987974    {'NEU': 8, 'NEG': 2, 'POS': 4}
# 97         NEG    0.739885  {'NEU': 11, 'NEG': 10, 'POS': 4}
# 98         NEG    0.990294    {'NEU': 2, 'NEG': 1, 'POS': 0}
# 99         NEG    0.932127    {'NEU': 2, 'NEG': 1, 'POS': 0}
